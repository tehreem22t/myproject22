# %%
import pandas as pd

# %%
import numpy as np

# %%
df= pd.read_csv("DATA (2).csv")

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
# Removing unwanted colummns
cleaned = df.drop(columns=['CustomerId', 'RowNumber','Geography'])
cleaned
# Out:
#          Surname  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0         Fields          619  Female   42       2       0.00              1
# 1       Johnston          608  Female   41       1   83807.86              1
# 2       Vasilyev          502  Female   42       8  159660.80              3
# 3         Hooper          699  Female   39       1       0.00              2
# 4        Colombo          850  Female   43       2  125510.82              1
# ...          ...          ...     ...  ...     ...        ...            ...
# 9995      Morgan          771    Male   39       5       0.00              2
# 9996     Nwebube          516    Male   35      10   57369.61              1
# 9997    Trevisan          709  Female   36       7       0.00              1
# 9998  Ositadimma          772    Male   42       3   75075.31              2
# 9999  Cunningham          792  Female   28       4  130142.79              1
#
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15598695    Fields          619    France  Female   42
# 1          2    15649354  Johnston          608     Spain  Female   41
# 2          3    15737556  Vasilyev          502    France  Female   42
# 3          4    15671610    Hooper          699    France  Female   39
# 4          5    15625092   Colombo          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# ...

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Complain',
#        'Satisfaction Score', 'Card Type', 'Point Earned'],
#       dtype='object')

# %%
df.tail(6)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 9994       9995    15585580       Chang          800    France  Female   29
# 9995       9996    15583480      Morgan          771    France    Male   39
# 9996       9997    15620341     Nwebube          516    France    Male   35
# 9997       9998    15613886    Trevisan          709    France  Female   36
# 9998       9999    15792916  Ositadimma          772   Germany    Male   42
# 9999      10000    15710408  Cunningham          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9994       2       0.00              2          0               0
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# ...

# %%
a=df.describe(include="all")

# %%
a.loc[["top","mean"]]
# Out:
#       RowNumber    CustomerId Surname  CreditScore Geography Gender      Age  \
# top         NaN           NaN   Smith          NaN    France   Male      NaN
# mean     5000.5  1.569094e+07     NaN     650.5288       NaN    NaN  38.9218
#
#       Tenure       Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# top      NaN           NaN            NaN        NaN             NaN
# mean  5.0128  76485.889288         1.5302     0.7055          0.5151
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# top               NaN     NaN       NaN                 NaN   DIAMOND
# mean    100090.239881  0.2038    0.2044              3.0138       NaN
#
#       Point Earned
# top            NaN
# mean      606.5151

# %%
a.iloc[[0,1,3]]
# Out:
#         RowNumber  CustomerId Surname  CreditScore Geography Gender      Age  \
# count     10000.0     10000.0   10000      10000.0     10000  10000  10000.0
# unique        NaN         NaN    2932          NaN         3      2      NaN
# freq          NaN         NaN      32          NaN      5014   5457      NaN
#
#          Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# count   10000.0  10000.0        10000.0    10000.0         10000.0
# unique      NaN      NaN            NaN        NaN             NaN
# freq        NaN      NaN            NaN        NaN             NaN
#
#         EstimatedSalary   Exited  Complain  Satisfaction Score Card Type  \
# count           10000.0  10000.0   10000.0             10000.0     10000
# unique              NaN      NaN       NaN                 NaN         4
# freq                NaN      NaN       NaN                 NaN      2507
#
#         Point Earned
# count        10000.0
# unique           NaN
# freq             NaN

# %%
a.iloc[[0,1,3],[1,2]]
# Out:
#         CustomerId Surname
# count      10000.0   10000
# unique         NaN    2932
# freq           NaN      32

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
filtered = df[["Age","Balance","Point Earned"]]
filtered.head()
# Out:
#    Age    Balance  Point Earned
# 0   42       0.00           464
# 1   41   83807.86           456
# 2   42  159660.80           377
# 3   39       0.00           350
# 4   43  125510.82           425

# %%
df["Balance"].mean()
# Out:
# 76485.889288

# %%
df["Balance"].median()
# Out:
# 97198.54000000001

# %%
df["Age"].mode()
# Out:
# 0    37
# Name: Age, dtype: int64

# %%
df["Balance"].value_counts()
# Out:
# Balance
# 0.00         3617
# 130170.82       2
# 105473.74       2
# 85304.27        1
# 159397.75       1
# 144238.70       1
# 112262.84       1
# 109106.80       1
# 142147.32       1
# 109109.33       1
# 146587.30       1
# 79896.00        1
# 132371.30       1
# 85859.76        1
# 69365.25        1
# 197715.93       1
# 95502.21        1
# 79857.64        1
# 142643.54       1
# 120923.52       1
# 126872.60       1
# 124213.36       1
# 138497.84       1
# 141952.07       1
# 125385.01       1
# 155271.83       1
# 172381.80       1
# 197200.04       1
# 127120.62       1
# 105103.33       1
# 98848.19        1
# 157274.36       1
# 104339.11       1
# 142946.18       1
# 109908.06       1
# 135847.47       1
# 108935.39       1
# 150300.65       1
# 131762.94       1
# 114453.58       1
# 128940.24       1
# 138106.75       1
# 143656.55       1
# 127406.50       1
# 107511.52       1
# 154377.30       1
# 125903.22       1
# 163085.79       1
# 144837.79       1
# ...

# %%
df['Age'].value_counts().plot(kind="bar",title="Age",color="blue")
# Out:
# <Axes: title={'center': 'Age'}, xlabel='Age'>

# %%
df.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# final balance         0
# dtype: int64

# %%
df[df["Point Earned"].isnull()]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited, Complain, Satisfaction Score, Card Type, Point Earned, final balance]
# Index: []

# %%
df["final balance"] = df["Age"].fillna(df["Age"].mean())

# %%
df[df["Age"].isnull()]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited, Complain, Satisfaction Score, Card Type, Point Earned, final balance]
# Index: []

# %%
df.groupby("Age").describe()
# Out:
#     RowNumber                                                              \
#         count         mean          std     min      25%     50%      75%
# Age
# 18       22.0  5641.818182  3357.650959   747.0  2439.25  4637.0  9384.00
# 19       27.0  4988.481481  2434.865869    58.0  3268.00  4771.0  6162.00
# 20       40.0  5358.825000  2762.193460   234.0  3009.75  5161.0  7535.00
# 21       53.0  4648.018868  2931.296021    70.0  2489.00  4048.0  6833.00
# 22       84.0  4791.654762  2811.067411    87.0  2630.00  4861.0  7331.25
# 23       99.0  5070.939394  2781.854431   405.0  2707.00  4715.0  7525.50
# 24      132.0  4748.000000  2912.878493    12.0  2007.75  4759.0  7013.25
# 25      154.0  4687.402597  2965.450347    14.0  2115.00  4596.0  7350.50
# 26      200.0  4823.830000  2912.162158    65.0  2373.50  4816.0  7033.00
# 27      209.0  5320.401914  2876.602716    10.0  2939.00  5379.0  7986.00
# 28      273.0  5178.190476  2938.225768    90.0  2662.00  5384.0  7629.00
# ...

# %%
df.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# final balance         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df["Age"].value_counts().plot(kind="hist",title="Age",color="purple")
# Out:
# <Axes: title={'center': 'Age'}, ylabel='Frequency'>

# %%
df["Age"].value_counts().plot(kind="pie",title="Age",color="yellow")
# Out:
# <Axes: title={'center': 'Age'}, ylabel='count'>

# %%
df["Gender"].value_counts().plot(kind="pie",title="Gender",color="red")
# Out:
# <Axes: title={'center': 'Gender'}, ylabel='count'>

# %%
df["Age"].value_counts().plot(kind="line",title="Age",color="pink")
# Out:
# <Axes: title={'center': 'Age'}, xlabel='Age'>

# %%
df.to_csv("DATA (2).csv")

# %%
df["Age"].value_counts().plot(kind="hist",title="Age",color="green")
# Out:
# <Axes: title={'center': 'Age'}, ylabel='Frequency'>
